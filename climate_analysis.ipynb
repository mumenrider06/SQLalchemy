# %%
import pandas as pd
import matplotlib
matplotlib.use('nbagg')
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
engine = create_engine('sqlite:///hawaii.sqlite')
conn = engine.connect()

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
hawaii_df = Base.classes.keys()
hawaii_df
# Out:
# ['Hawaii', 'hawaii_measurements', 'hawaii_stations']

# %%
Station = Base.classes.hawaii_stations
Measurement = Base.classes.hawaii_measurements
session = Session(engine)

# %%
first_row = session.query(Measurement).first()

# %%
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x10b0be978>,
#  'date': '2010-01-01',
#  'id': 1,
#  'prcp': 0.08,
#  'station': 'USC00519397',
#  'tobs': 65}

# %%
last12 = session.query(Measurement.date, Measurement.prcp).first()

last12
# Out:
# ('2010-01-01', 0.08)

# %%
meas = pd.DataFrame(session.query(Measurement.date, Measurement.prcp).all())
meas.head()
# Out:
#          date  prcp
# 0  2010-01-01  0.08
# 1  2010-01-02  0.00
# 2  2010-01-03  0.00
# 3  2010-01-04  0.00
# 4  2010-01-07  0.06

# %%
meas2 = pd.DataFrame()
for index, row in meas.iterrows():
    parsed = row[0].replace('-', '')
    meas2.set_value(index, 'date', parsed)
    meas2.set_value(index, 'prcp', row[1])
    
meas2.head()
# Out:
#        date  prcp
# 0  20100101  0.08
# 1  20100102  0.00
# 2  20100103  0.00
# 3  20100104  0.00
# 4  20100107  0.06

# %%
meas2.date = meas2.date.astype(int)
meas2.head()
# Out:
#        date  prcp
# 0  20100101  0.08
# 1  20100102  0.00
# 2  20100103  0.00
# 3  20100104  0.00
# 4  20100107  0.06

# %%
meas3 = meas2[meas2.date > 20160824]
meas3.head()
# Out:
#           date  prcp
# 2328  20160825  0.08
# 2329  20160826  0.00
# 2330  20160827  0.00
# 2331  20160828  0.01
# 2332  20160829  0.00

# %%
meas3.date = meas3.date.astype(str)
plt.bar(meas3.date, meas3.prcp)
# Out:
# /Users/Sausage/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# <Container object of 2009 artists>

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.4444656224904">

# %%
meas3.plot.bar('date', 'prcp')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.4444656224904">

# %%
meas3.describe()
# Out:
#               prcp
# count  2009.000000
# mean      0.172344
# std       0.452818
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# # Stations Analysis

# %%
first_row = session.query(Station).first()

# %%
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x11b169da0>,
#  'elevation': 3.0,
#  'id': 1,
#  'latitude': 21.2716,
#  'longitude': -157.8168,
#  'name': 'WAIKIKI 717.2, HI US',
#  'station': 'USC00519397'}

# %%
all_stations = session.query(Station).all()

# %%
all_meas = pd.DataFrame(session.query(Measurement.date, Measurement.id, Measurement.prcp, Measurement.station, Measurement.tobs).all())

# %%
all_stat = pd.DataFrame(session.query(Station.elevation, Station.id, Station.latitude, Station.longitude, Station.name, Station.station).all())

# %%
all_meas.head()
# Out:
#          date  id  prcp      station  tobs
# 0  2010-01-01   1  0.08  USC00519397    65
# 1  2010-01-02   2  0.00  USC00519397    63
# 2  2010-01-03   3  0.00  USC00519397    74
# 3  2010-01-04   4  0.00  USC00519397    76
# 4  2010-01-07   5  0.06  USC00519397    70

# %%
all_stat
# Out:
#    elevation  id  latitude  longitude                                    name  \
# 0        3.0   1  21.27160 -157.81680                    WAIKIKI 717.2, HI US
# 1       14.6   2  21.42340 -157.80150                    KANEOHE 838.1, HI US
# 2        7.0   3  21.52130 -157.83740  KUALOA RANCH HEADQUARTERS 886.9, HI US
# 3       11.9   4  21.39340 -157.97510                       PEARL CITY, HI US
# 4      306.6   5  21.49920 -158.01110              UPPER WAHIAWA 874.3, HI US
# 5       19.5   6  21.33556 -157.71139      WAIMANALO EXPERIMENTAL FARM, HI US
# 6       32.9   7  21.45167 -157.84889                     WAIHEE 837.5, HI US
# 7        0.9   8  21.31520 -157.99920       HONOLULU OBSERVATORY 702.2, HI US
# 8      152.4   9  21.33310 -157.80250            MANOA LYON ARBO 785.2, HI US
#
#        station
# 0  USC00519397
# 1  USC00513117
# 2  USC00514830
# 3  USC00517948
# 4  USC00518838
# 5  USC00519523
# 6  USC00519281
# 7  USC00511918
# 8  USC00516128

# %%
grouped = all_meas.groupby('station').id.count()

# %%
groups_sorted = grouped.sort_values(ascending=False)
groups_sorted
# Out:
# station
# USC00519281    2772
# USC00513117    2696
# USC00519397    2685
# USC00519523    2572
# USC00516128    2484
# USC00514830    1937
# USC00511918    1932
# USC00517948     683
# USC00518838     342
# Name: id, dtype: int64

# %%
just_waihee = all_meas[all_meas.station == 'USC00519281']
just_waihee.tobs.hist(bins=12)
plt.xlabel('Degrees Farenheit')
plt.ylabel('Frequency')
plt.title('Frequency of Waihee Temperature Observations')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.4444656224904">

# %% [markdown]
# # Temperature Analysis

# %%
all_meas.date.dtype
# Out:
# dtype('O')

# %%
all_meas.head()
# Out:
#          date  id  prcp      station  tobs
# 0  2010-01-01   1  0.08  USC00519397    65
# 1  2010-01-02   2  0.00  USC00519397    63
# 2  2010-01-03   3  0.00  USC00519397    74
# 3  2010-01-04   4  0.00  USC00519397    76
# 4  2010-01-07   5  0.06  USC00519397    70

# %%
new_all_meas = pd.DataFrame()
for index, row in all_meas.iterrows():
    parsed = row[0].replace('-', '')
    new_all_meas.set_value(index, 'date', parsed)
    new_all_meas.set_value(index, 'prcp', row[2])
    new_all_meas.set_value(index, 'id', row[1])
    new_all_meas.set_value(index, 'station', row[3])
    new_all_meas.set_value(index, 'tobs', row[4])

# %%
new_all_meas['date'] = new_all_meas['date'].astype(int)
new_all_meas.head()
# Out:
#        date  prcp   id      station  tobs
# 0  20100101  0.08  1.0  USC00519397  65.0
# 1  20100102  0.00  2.0  USC00519397  63.0
# 2  20100103  0.00  3.0  USC00519397  74.0
# 3  20100104  0.00  4.0  USC00519397  76.0
# 4  20100107  0.06  5.0  USC00519397  70.0

# %%
new_all_meas.date.dtype

# %%
def calc_temps(start_date, end_date):
    parsed_start = int(start_date.replace('-', ''))
    parsed_end = int(end_date.replace('-', ''))
    subset_meas = new_all_meas[(new_all_meas.date >= parsed_start) & (new_all_meas.date <= parsed_end)]
    maxtemp = subset_meas.tobs.max()
    mintemp = subset_meas.tobs.min()
    avgtemp = subset_meas.tobs.mean()
    print('For date range selected, the:\nMax temp is: ', maxtemp, '\nMin temp is: ', mintemp, '\nAverage temp is: ', avgtemp)
    return maxtemp, mintemp, avgtemp

# %%
maxtemp, mintemp, avgtemp = calc_temps('2011-01-05', '2011-01-27')
# Out:
# For date range selected, the:
# Max temp is:  76.0
# Min temp is:  57.0
# Average temp is:  67.34254143646409

# %%
plt.bar(0, avgtemp, yerr=(maxtemp - mintemp))
plt.ylabel('Degrees Farenheit')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')
plt.title('Average Temperature Over Trip Duration')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.4444656224904">

# %%
adict = new_all_meas[['date', 'prcp']].set_index('date').to_dict()
adict
# Out:
# {'prcp': {20100101: 0.14000000000000001,
#   20100102: 0.0,
#   20100103: 0.0,
#   20100104: 0.0,
#   20100107: 0.29999999999999999,
#   20100108: 0.0,
#   20100109: 0.0,
#   20100110: 0.01,
#   20100111: 0.14000000000000001,
#   20100112: 0.0,
#   20100114: 0.0,
#   20100115: 0.0,
#   20100116: 0.0,
#   20100117: 0.0,
#   20100118: 0.0,
#   20100119: 0.0,
#   20100120: 0.0,
#   20100121: 0.32000000000000001,
#   20100122: 0.0,
#   20100123: 0.0,
#   20100124: 0.01,
#   20100125: 0.0,
#   20100126: 0.029999999999999999,
#   20100127: 0.31,
#   20100128: 0.070000000000000007,
#   20100131: 1.1000000000000001,
#   20100201: 0.01,
#   20100204: 0.0,
#   20100205: 0.089999999999999997,
#   20100206: 0.040000000000000001,
#   20100207: 0.0,
#   20100208: 0.0,
#   20100209: 0.0,
#   20100211: 0.0,
#   20100212: 0.65000000000000002,
#   20100213: 0.62,
#   20100214: 0.02,
#   20100215: 0.0,
#   20100216: 0.0,
#   20100217: 0.02,
#   20100220: 0.55000000000000004,
#   20100221: 0.0,
#   20100222: 0.0,
#   20100223: 0.0,
#   20100224: 0.0,
#   20100225: 0.0,
#   20100226: 0.01,
#   20100228: 0.20000000000000001,
#   20100301: 0.12,
#   20100302: 0.0,
#   20100303: 0.12,
#   20100304: 1.4099999999999999,
#   20100305: 1.3300000000000001,
#   20100306: 0.90000000000000002,
#   20100307: 0.34999999999999998,
#   20100308: 0.69999999999999996,
#   20100309: 0.23999999999999999,
#   20100312: 0.029999999999999999,
#   20100313: 0.10000000000000001,
#   20100314: 0.10000000000000001,
#   20100315: 0.82999999999999996,
#   20100317: 1.3200000000000001,
#   20100318: 0.11,
#   20100321: 1.0,
#   20100322: 0.0,
#   20100323: 0.0,
#   20100324: 0.070000000000000007,
#   20100327: 0.0,
#   20100328: 0.0,
#   20100329: 0.02,
#   20100330: 0.48999999999999999,
#   20100331: 0.080000000000000002,
#   20100401: 0.040000000000000001,
#   20100402: 0.19,
#   20100403: 0.92000000000000004,
#   20100404: 2.5600000000000001,
#   20100405: 0.87,
#   20100406: 1.8300000000000001,
#   20100408: 0.34999999999999998,
#   20100409: 0.5,
#   20100410: 0.40000000000000002,
#   20100411: 1.04,
#   20100412: 0.02,
#   20100413: 0.93000000000000005,
#   20100415: 0.0,
#   20100416: 0.059999999999999998,
#   20100417: 0.029999999999999999,
#   20100418: 0.029999999999999999,
#   20100419: 0.01,
#   20100420: 0.68000000000000005,
#   20100421: 0.17000000000000001,
#   20100422: 0.0,
#   20100423: 0.01,
#   20100424: 0.17000000000000001,
#   20100425: 0.080000000000000002,
#   20100426: 0.0,
#   20100428: 0.48999999999999999,
#   20100430: 0.92000000000000004,
#   20100501: 0.31,
#   20100502: 0.37,
#   20100503: 0.14000000000000001,
#   20100504: 0.20999999999999999,
#   20100505: 0.01,
#   20100506: 0.080000000000000002,
#   20100507: 0.23999999999999999,
#   20100508: 0.059999999999999998,
#   20100509: 0.0,
#   20100510: 0.55000000000000004,
#   20100511: 0.0,
#   20100513: 0.32000000000000001,
#   20100514: 0.0,
#   20100515: 0.25,
#   20100516: 0.60999999999999999,
#   20100517: 0.10000000000000001,
#   20100518: 0.0,
#   20100519: 0.0,
#   20100522: 0.01,
#   20100523: 0.0,
#   20100524: 0.0,
#   20100525: 0.82999999999999996,
#   20100526: 0.27000000000000002,
#   20100527: 0.050000000000000003,
#   20100528: 0.0,
#   20100529: 0.80000000000000004,
#   20100530: 0.01,
#   20100531: 0.0,
#   20100601: 0.080000000000000002,
#   20100602: 0.0,
#   20100603: 0.10000000000000001,
#   20100604: 0.01,
#   20100605: 0.089999999999999997,
#   20100606: 0.13,
#   20100607: 0.44,
#   20100608: 0.27000000000000002,
#   20100609: 0.0,
#   20100610: 0.0,
#   20100611: 0.0,
#   20100612: 0.0,
#   20100613: 0.040000000000000001,
#   20100614: 0.0,
#   20100615: 0.0,
#   20100616: 0.0,
#   20100617: 0.050000000000000003,
#   20100618: 0.040000000000000001,
#   20100619: 0.050000000000000003,
#   20100620: 0.0,
#   20100621: 0.0,
#   20100622: 0.0,
#   20100623: 0.040000000000000001,
#   20100624: 0.26000000000000001,
#   20100625: 0.79000000000000004,
#   20100626: 0.88,
#   20100627: 0.37,
#   20100628: 0.16,
#   20100629: 0.02,
#   20100630: 0.70999999999999996,
#   20100701: 0.44,
#   20100702: 0.69999999999999996,
#   20100703: 1.8100000000000001,
#   20100704: 0.44,
#   20100705: 0.14000000000000001,
#   20100706: 1.01,
#   20100707: 1.05,
#   20100708: 0.90000000000000002,
#   20100709: 0.75,
#   20100710: 0.75,
#   20100711: 0.31,
#   20100712: 0.25,
#   20100713: 0.0,
#   20100717: 0.46000000000000002,
#   20100718: 2.1400000000000001,
#   20100719: 0.34999999999999998,
#   20100721: 0.050000000000000003,
#   20100722: 0.070000000000000007,
#   20100724: 0.040000000000000001,
#   20100725: 0.0,
#   20100726: 0.0,
#   20100727: 0.10000000000000001,
#   20100728: 0.02,
#   20100729: 0.38,
#   20100730: 0.28999999999999998,
#   20100731: 0.050000000000000003,
#   20100801: 0.52000000000000002,
#   20100802: 1.45,
#   20100803: 0.57999999999999996,
#   20100804: 1.8899999999999999,
#   20100805: 0.93000000000000005,
#   20100806: 0.34999999999999998,
#   20100807: 0.17999999999999999,
#   20100808: 0.81999999999999995,
#   20100809: 0.089999999999999997,
#   20100810: 0.029999999999999999,
#   20100811: 0.13,
#   20100812: 0.029999999999999999,
#   20100813: 0.14000000000000001,
#   20100814: 0.0,
#   20100815: 0.0,
#   20100816: 0.41999999999999998,
#   20100817: 0.88,
#   20100818: 0.080000000000000002,
#   20100819: 0.12,
#   20100820: 0.23999999999999999,
#   20100821: 0.059999999999999998,
#   20100822: 0.02,
#   20100823: 0.059999999999999998,
#   20100824: 0.40999999999999998,
#   20100825: 0.45000000000000001,
#   20100826: 0.60999999999999999,
#   20100827: 1.1299999999999999,
#   20100828: 0.40999999999999998,
#   20100829: 1.0,
#   20100830: 0.17999999999999999,
#   20100831: 0.20999999999999999,
#   20100901: 0.20999999999999999,
#   20100902: 0.54000000000000004,
#   20100903: 0.52000000000000002,
#   20100904: 0.32000000000000001,
#   20100905: 0.070000000000000007,
#   20100906: 0.38,
#   20100907: 1.51,
#   20100908: 0.28000000000000003,
#   20100909: 0.01,
#   20100910: 0.17999999999999999,
#   20100911: 0.23999999999999999,
#   20100912: 0.0,
#   20100913: 0.0,
#   20100914: 0.27000000000000002,
#   20100915: 0.040000000000000001,
#   20100916: 0.20999999999999999,
#   20100917: 0.0,
#   20100919: 0.57999999999999996,
#   20100920: 0.26000000000000001,
#   20100921: 0.040000000000000001,
#   20100922: 0.41999999999999998,
#   20100923: 0.85999999999999999,
#   20100924: 0.0,
#   20100925: 0.56999999999999995,
#   20100926: 0.0,
#   20100927: 0.0,
#   20100928: 0.0,
#   20100929: 0.0,
#   20100930: 1.1799999999999999,
#   20101001: 3.1400000000000001,
#   20101002: 1.27,
#   20101003: 0.029999999999999999,
#   20101004: 0.23999999999999999,
#   20101005: 0.20999999999999999,
#   20101006: 0.0,
#   20101007: 0.0,
#   20101008: 0.0,
#   20101009: 0.0,
#   20101010: 0.0,
#   20101011: 0.40999999999999998,
#   20101012: 0.25,
#   20101013: 0.050000000000000003,
#   20101015: 0.01,
#   20101016: 0.080000000000000002,
#   20101017: 0.20999999999999999,
#   20101018: 0.070000000000000007,
#   20101019: 4.0099999999999998,
#   20101020: 0.0,
#   20101021: 0.39000000000000001,
#   20101022: 0.20999999999999999,
#   20101023: 0.0,
#   20101024: 0.0,
#   20101025: 0.0,
#   20101026: 0.68000000000000005,
#   20101027: 1.0600000000000001,
#   20101028: 0.69999999999999996,
#   20101029: 0.23999999999999999,
#   20101030: 1.8999999999999999,
#   20101031: 0.28000000000000003,
#   20101101: 2.0299999999999998,
#   20101102: 0.46999999999999997,
#   20101105: 2.6400000000000001,
#   20101106: 4.5599999999999996,
#   20101107: 0.54000000000000004,
#   20101108: 0.01,
#   20101109: 0.01,
#   20120204: 0.0,
#   20120205: 0.0,
#   20120206: 0.0,
#   20120207: 0.69999999999999996,
#   20120208: 0.44,
#   20120209: 0.0,
#   20120210: 0.0,
#   20120211: 0.0,
#   20120212: 0.070000000000000007,
#   20120213: 1.26,
#   20120214: 0.02,
#   20120215: 0.0,
#   20120216: 0.0,
#   20120217: 0.29999999999999999,
#   20120218: 0.67000000000000004,
#   20120219: 1.29,
#   20120220: 0.029999999999999999,
#   20120221: 0.0,
#   20120222: 0.0,
#   20120223: 1.3100000000000001,
#   20120224: 0.77000000000000002,
#   20120225: 0.02,
#   20120226: 0.29999999999999999,
#   20120227: 0.44,
#   20120228: 0.40000000000000002,
#   20120229: 0.55000000000000004,
#   20120301: 0.64000000000000001,
#   20120302: 0.26000000000000001,
#   20120303: 1.1000000000000001,
#   20120304: 2.0,
#   20120305: 5.3700000000000001,
#   20120306: 2.6099999999999999,
#   20120307: 2.6299999999999999,
#   20120308: 2.0899999999999999,
#   20120309: 3.23,
#   20120310: 0.14999999999999999,
#   20120311: 0.31,
#   20120312: 1.6000000000000001,
#   20120313: 0.45000000000000001,
#   20120314: 0.01,
#   20120315: 0.029999999999999999,
#   20120316: 0.080000000000000002,
#   20120317: 0.02,
#   20120318: 0.65000000000000002,
#   20120319: 1.6100000000000001,
#   20120320: 0.0,
#   20120321: 0.42999999999999999,
#   20120322: 0.47999999999999998,
#   20120323: 0.050000000000000003,
#   20120324: 0.059999999999999998,
#   20120325: 1.9199999999999999,
#   20120326: 0.37,
#   20120327: 0.56999999999999995,
#   20120328: 0.02,
#   20120329: 0.0,
#   20120330: 0.0,
#   20120331: 0.0,
#   20120401: 0.040000000000000001,
#   20120402: 0.0,
#   20120403: 0.0,
#   20120404: 0.029999999999999999,
#   20120405: 0.89000000000000001,
#   20120406: 0.10000000000000001,
#   20120407: 1.75,
#   20120408: 0.02,
#   20120409: 3.27,
#   20120410: 1.3200000000000001,
#   20120411: 1.47,
#   20120412: 0.14999999999999999,
#   20120413: 0.01,
#   20120414: 0.01,
#   20120415: 0.17999999999999999,
#   20120416: 0.12,
#   20120417: 0.01,
#   20120418: 0.01,
#   20120419: 0.029999999999999999,
#   20120420: 0.040000000000000001,
#   20120421: 0.0,
#   20120422: 0.080000000000000002,
#   20120423: 1.6200000000000001,
#   20120424: 0.20000000000000001,
#   20120425: 0.29999999999999999,
#   20120426: 0.60999999999999999,
#   20120427: 0.02,
#   20120428: 0.65000000000000002,
#   20120429: 0.20000000000000001,
#   20120430: 0.12,
#   20120501: 0.029999999999999999,
#   20120502: 0.56999999999999995,
#   20120503: 0.16,
#   20120504: 1.21,
#   20120505: 0.90000000000000002,
#   20120506: 0.14000000000000001,
#   20120507: 0.54000000000000004,
#   20120508: 0.02,
#   20120509: 0.040000000000000001,
#   20120510: 0.0,
#   20120511: 0.23000000000000001,
#   20120512: 0.01,
#   20120513: 0.0,
#   20120514: 0.0,
#   20120515: 0.0,
#   20120516: 0.029999999999999999,
#   20120517: 0.02,
#   20120518: 0.050000000000000003,
#   20120519: 0.0,
#   20120520: 0.02,
#   20120521: 0.20000000000000001,
#   20120522: 0.0,
#   20120523: 0.0,
#   20120524: 0.070000000000000007,
#   20120525: 0.13,
#   20120526: 0.37,
#   20120527: 0.67000000000000004,
#   20120528: 0.13,
#   20120529: 0.029999999999999999,
#   20120530: 0.01,
#   20120531: 0.62,
#   20120601: 0.26000000000000001,
#   20120602: 0.22,
#   20120603: 0.0,
#   20120604: 0.02,
#   20120605: 0.0,
#   20120606: 0.71999999999999997,
#   20120607: 0.12,
#   20120610: 0.080000000000000002,
#   20120611: 0.080000000000000002,
#   20120612: 0.14000000000000001,
#   20120613: 0.47999999999999998,
#   20120614: 0.20999999999999999,
#   20120615: 0.0,
#   20120616: 0.0,
#   20120617: 0.10000000000000001,
#   20120618: 0.0,
#   20120619: 0.38,
#   20120620: 1.8400000000000001,
#   20120621: 0.34000000000000002,
#   20120622: 0.0,
#   20120623: 0.93999999999999995,
#   20120624: 1.1299999999999999,
#   20120625: 0.89000000000000001,
#   20120626: 0.92000000000000004,
#   20120627: 0.72999999999999998,
#   20120628: 0.37,
#   20120629: 0.79000000000000004,
#   20120630: 0.0,
#   20120701: 0.0,
#   20120702: 0.050000000000000003,
#   20120703: 1.04,
#   20120704: 0.84999999999999998,
#   20120705: 0.97999999999999998,
#   20120706: 1.0800000000000001,
#   20120707: 0.85999999999999999,
#   20120708: 0.050000000000000003,
#   20120710: 0.12,
#   20120711: 0.39000000000000001,
#   20120712: 0.0,
#   20120713: 0.52000000000000002,
#   20120714: 0.28999999999999998,
#   20120715: 0.059999999999999998,
#   20120716: 0.82999999999999996,
#   20120717: 0.70999999999999996,
#   20120718: 1.0,
#   20120719: 0.34000000000000002,
#   20120720: 0.13,
#   20120721: 0.029999999999999999,
#   20120722: 0.040000000000000001,
#   20120723: 0.28999999999999998,
#   20120724: 0.0,
#   20120725: 0.17999999999999999,
#   20120726: 0.0,
#   20120727: 0.23000000000000001,
#   20120728: 0.5,
#   20120729: 2.8700000000000001,
#   20120730: 0.35999999999999999,
#   20120731: 0.58999999999999997,
#   20120801: 0.050000000000000003,
#   20120802: 0.0,
#   20120803: 0.089999999999999997,
#   20120804: 0.059999999999999998,
#   20120805: 0.44,
#   20120806: 0.29999999999999999,
#   20120807: 0.22,
#   20120808: 0.44,
#   20120809: 0.14000000000000001,
#   20120810: 0.02,
#   20120811: 0.26000000000000001,
#   20120812: 0.23000000000000001,
#   20120813: 0.029999999999999999,
#   20120814: 0.26000000000000001,
#   20120815: 0.02,
#   20120816: 0.0,
#   20120817: 0.23999999999999999,
#   20120820: 0.38,
#   20120821: 0.40999999999999998,
#   20120822: 0.23999999999999999,
#   20120823: 0.089999999999999997,
#   20120824: 0.53000000000000003,
#   20120825: 0.0,
#   20120826: 0.0,
#   20120827: 0.0,
#   20120828: 1.1899999999999999,
#   20120829: 0.90000000000000002,
#   20120830: 0.44,
#   20120831: 0.26000000000000001,
#   20120901: 0.10000000000000001,
#   20120902: 0.46000000000000002,
#   20120903: 0.19,
#   20120904: 0.050000000000000003,
#   20120905: 0.58999999999999997,
#   20120906: 0.20000000000000001,
#   20120907: 1.24,
#   20120908: 2.48,
#   20120909: 2.5699999999999998,
#   20120910: 0.19,
#   20120911: 0.0,
#   20120912: 0.23000000000000001,
#   20120913: 0.040000000000000001,
#   20120914: 0.52000000000000002,
#   20120915: 0.40999999999999998,
#   20120916: 0.62,
#   20120917: 0.29999999999999999,
#   20120918: 0.38,
#   20120919: 0.34999999999999998,
#   20120920: 0.16,
#   20120921: 0.39000000000000001,
#   20120922: 0.17000000000000001,
#   20120923: 0.98999999999999999,
#   20120924: 1.5800000000000001,
#   20120925: 0.56000000000000005,
#   20120926: 0.29999999999999999,
#   20120927: 0.12,
#   20120928: 0.31,
#   20120929: 0.0,
#   20120930: 0.0,
#   20121001: 0.0,
#   20121002: 0.0,
#   20121003: 0.0,
#   20121004: 0.0,
#   20121005: 0.0,
#   20121006: 0.0,
#   20121007: 0.01,
#   20121008: 0.0,
#   20121009: 0.0,
#   20121010: 0.0,
#   20121011: 0.40000000000000002,
#   20121012: 0.0,
#   20121013: 0.0,
#   20121014: 0.02,
#   20121015: 0.02,
#   20121016: 0.0,
#   20121017: 0.0,
#   20121018: 0.0,
#   20121019: 0.0,
#   20121020: 0.0,
#   20121021: 0.0,
#   20121022: 0.0,
#   20121023: 0.080000000000000002,
#   20121024: 0.0,
#   20121025: 0.0,
#   20121026: 0.01,
#   20121027: 0.0,
#   20121028: 0.48999999999999999,
#   20121029: 0.53000000000000003,
#   20121030: 0.20000000000000001,
#   20121031: 0.20000000000000001,
#   20121101: 0.0,
#   20121102: 0.0,
#   20121103: 0.0,
#   20121104: 0.0,
#   20121105: 0.02,
#   20121106: 0.64000000000000001,
#   20121107: 0.089999999999999997,
#   20121108: 0.51000000000000001,
#   20121109: 0.27000000000000002,
#   20121110: 0.14999999999999999,
#   20121111: 0.02,
#   20121112: 0.28000000000000003,
#   20121113: 0.41999999999999998,
#   20121114: 0.20000000000000001,
#   20121115: 0.64000000000000001,
#   20121116: 0.73999999999999999,
#   20121117: 0.17999999999999999,
#   20121118: 0.14999999999999999,
#   20121119: 0.0,
#   20121120: 0.35999999999999999,
#   20121121: 0.11,
#   20121122: 0.0,
#   20121123: 0.0,
#   20121124: 0.0,
#   20121125: 0.0,
#   20121126: 0.53000000000000003,
#   20121127: 0.01,
#   20121128: 0.01,
#   20121129: 0.0,
#   20121130: 0.0,
#   20121201: 0.0,
#   20121202: 0.01,
#   20121203: 0.0,
#   20121204: 0.0,
#   20121205: 0.040000000000000001,
#   20121208: 0.01,
#   20121209: 0.040000000000000001,
#   20121210: 0.12,
#   20121211: 0.0,
#   20121212: 0.23999999999999999,
#   20121213: 0.44,
#   20121214: 0.71999999999999997,
#   20121215: 0.44,
#   20121216: 0.47999999999999998,
#   20121217: 0.54000000000000004,
#   ...}}
